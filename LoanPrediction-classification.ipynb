# %% [markdown]
# # LoanPrediction

# %% [markdown]
# Data Dictionary
#
# The dataset consists of the following fields:
# • Loan ID: A unique Identifier for the loan information.
# • Customer ID: A unique identifier for the customer. Customers may have more than one loan.
# • Loan Status: A categorical variable indicating if the loan was paid back or defaulted.
# • Current Loan Amount: This is the loan amount that was either completely paid off, or the amount that was defaulted.
# • Term: A categorical variable indicating if it is a short term or long term loan.
# • Credit Score: A value between 0 and 800 indicating the riskiness of the borrowers credit history.
# • Years in current job: A categorical variable indicating how many years the customer has been in their current job.
# • Home Ownership: Categorical variable indicating home ownership. Values are "Rent", "Home Mortgage", and "Own". If the value is OWN, then the customer is a home owner with no mortgage
# • Annual Income: The customer's annual income
# • Purpose: A description of the purpose of the loan.
# • Monthly Debt: The customer's monthly payment for their existing loans
# • Years of Credit History: The years since the first entry in the customer’s credit history • Months since last delinquent: Months since the last loan delinquent payment
# • Number of Open Accounts: The total number of open credit cards
# • Number of Credit Problems: The number of credit problems in the customer records.
# • Current Credit Balance: The current total debt for the customer
# • Maximum Open Credit: The maximum credit limit for all credit sources.
# • Bankruptcies: The number of bankruptcies
# • Tax Liens: The number of tax liens.

# %%
import pandas as pd

# %%
df=pd.read_csv('LoansTrainingSet.csv')
# Out:
# C:\Users\w10\AppData\Local\Temp\ipykernel_14624\841172785.py:1: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('LoansTrainingSet.csv')

# %%
df
# Out:
#                                      Loan ID  \
# 0       000025bb-5694-4cff-b17d-192b1a98ba44
# 1       00002c49-3a29-4bd4-8f67-c8f8fbc1048c
# 2       00002d89-27f3-409b-aa76-90834f359a65
# 3       00005222-b4d8-45a4-ad8c-186057e24233
# 4       0000757f-a121-41ed-b17b-162e76647c1f
# ...                                      ...
# 256979  fffef5b7-be99-4666-ac70-2a397d2ee435
# 256980  ffffca93-aa8c-4123-b8ff-7852f6df889a
# 256981  ffffcb2e-e48e-4d2c-a0d6-ed6bce5bfdbe
# 256982  ffffcb2e-e48e-4d2c-a0d6-ed6bce5bfdbe
# 256983  ffffe32e-ed17-459f-9cfd-7b9ee7972933
#
#                                  Customer ID  Loan Status  \
# 0       5ebc8bb1-5eb9-4404-b11b-a6eebc401a19   Fully Paid
# 1       927b388d-2e01-423f-a8dc-f7e42d668f46   Fully Paid
# 2       defce609-c631-447d-aad6-1270615e89c4   Fully Paid
# 3       070bcecb-aae7-4485-a26a-e0403e7bb6c5   Fully Paid
# 4       dde79588-12f0-4811-bab0-e2b07f633fcd   Fully Paid
# ...                                      ...          ...
# ...

# %%
df['Term'].value_counts()
# Out:
# Term
# Short Term    192632
# Long Term      64352
# Name: count, dtype: int64

# %%
import pandas as pd
import re

# Özel fonksiyonun tanımlanması
def remove_non_numeric(value):
    if isinstance(value, str):
        # Sayı harici karakterleri kaldırma
        value = re.sub(r'[^0-9]', '', value)
    return value

# %%
df['Years in current job']= df['Years in current job'].apply(remove_non_numeric)

# %%
df['Years in current job'] = pd.to_numeric(df['Years in current job'], errors='coerce').fillna(0).astype(int)

# %%
df['Years in current job'].mean()
# Out:
# 5.6890584627836756

# %%
mean_value = df[df['Years in current job'] != 0]['Years in current job'].mean()
df['Years in current job'] = df['Years in current job'].replace(0, mean_value)

# %%
df['Years in current job'].isnull().sum()
# Out:
# 0

# %%
df
# Out:
#                                      Loan ID  \
# 0       000025bb-5694-4cff-b17d-192b1a98ba44
# 1       00002c49-3a29-4bd4-8f67-c8f8fbc1048c
# 2       00002d89-27f3-409b-aa76-90834f359a65
# 3       00005222-b4d8-45a4-ad8c-186057e24233
# 4       0000757f-a121-41ed-b17b-162e76647c1f
# ...                                      ...
# 256979  fffef5b7-be99-4666-ac70-2a397d2ee435
# 256980  ffffca93-aa8c-4123-b8ff-7852f6df889a
# 256981  ffffcb2e-e48e-4d2c-a0d6-ed6bce5bfdbe
# 256982  ffffcb2e-e48e-4d2c-a0d6-ed6bce5bfdbe
# 256983  ffffe32e-ed17-459f-9cfd-7b9ee7972933
#
#                                  Customer ID  Loan Status  \
# 0       5ebc8bb1-5eb9-4404-b11b-a6eebc401a19   Fully Paid
# 1       927b388d-2e01-423f-a8dc-f7e42d668f46   Fully Paid
# 2       defce609-c631-447d-aad6-1270615e89c4   Fully Paid
# 3       070bcecb-aae7-4485-a26a-e0403e7bb6c5   Fully Paid
# 4       dde79588-12f0-4811-bab0-e2b07f633fcd   Fully Paid
# ...                                      ...          ...
# ...

# %%
def temiz(x):
        df[x]= df[x].apply(remove_non_numeric)
        df[x] = pd.to_numeric(df[x], errors='coerce').fillna(0).astype(int)
        mean_value = df[df[x] != 0][x].mean()
        df[x] = df[x].replace(0, mean_value)

# %%
temiz('Credit Score')

# %%
df['Credit Score'].mean()
# Out:
# 1251.1160986749135

# %%
df['Credit Score'].isnull().sum()
# Out:
# 0

# %%
df
# Out:
#                                      Loan ID  \
# 0       000025bb-5694-4cff-b17d-192b1a98ba44
# 1       00002c49-3a29-4bd4-8f67-c8f8fbc1048c
# 2       00002d89-27f3-409b-aa76-90834f359a65
# 3       00005222-b4d8-45a4-ad8c-186057e24233
# 4       0000757f-a121-41ed-b17b-162e76647c1f
# ...                                      ...
# 256979  fffef5b7-be99-4666-ac70-2a397d2ee435
# 256980  ffffca93-aa8c-4123-b8ff-7852f6df889a
# 256981  ffffcb2e-e48e-4d2c-a0d6-ed6bce5bfdbe
# 256982  ffffcb2e-e48e-4d2c-a0d6-ed6bce5bfdbe
# 256983  ffffe32e-ed17-459f-9cfd-7b9ee7972933
#
#                                  Customer ID  Loan Status  \
# 0       5ebc8bb1-5eb9-4404-b11b-a6eebc401a19   Fully Paid
# 1       927b388d-2e01-423f-a8dc-f7e42d668f46   Fully Paid
# 2       defce609-c631-447d-aad6-1270615e89c4   Fully Paid
# 3       070bcecb-aae7-4485-a26a-e0403e7bb6c5   Fully Paid
# 4       dde79588-12f0-4811-bab0-e2b07f633fcd   Fully Paid
# ...                                      ...          ...
# ...

# %%
temiz('Annual Income')

# %%
temiz('Monthly Debt')

# %%
temiz('Years of Credit History')

# %%
temiz('Months since last delinquent')

# %%
temiz('Number of Open Accounts')

# %%
temiz('Current Credit Balance')

# %%
temiz('Maximum Open Credit')

# %%
temiz('Tax Liens')

# %%
df['Bankruptcies'].isnull().sum()
# Out:
# 529

# %%
df['Bankruptcies'] = pd.to_numeric(df['Bankruptcies'], errors='coerce').fillna(0).astype(int)

# %%
df.corr(numeric_only=True)
# Out:
#                               Current Loan Amount  Credit Score  \
# Current Loan Amount                      1.000000     -0.136195
# Credit Score                            -0.136195      1.000000
# Years in current job                     0.005430     -0.000489
# Annual Income                            0.023455     -0.033223
# Monthly Debt                            -0.001979      0.004855
# Years of Credit History                  0.014812     -0.010050
# Months since last delinquent             0.002440     -0.005020
# Number of Open Accounts                 -0.003111      0.007100
# Number of Credit Problems               -0.000062      0.000681
# Current Credit Balance                   0.003309     -0.003022
# Maximum Open Credit                      0.006503     -0.001985
# Bankruptcies                             0.003577     -0.002939
# Tax Liens                                0.000040      0.000865
#
#                               Years in current job  Annual Income  \
# ...

# %%
df.describe()
# Out:
#        Current Loan Amount   Credit Score  Years in current job  \
# count         2.569840e+05  256984.000000         256984.000000
# mean          1.371331e+07    1251.116099              5.954987
# std           3.438131e+07    1536.090361              3.417748
# min           5.050000e+02     585.000000              1.000000
# 25%           8.299000e+03     722.000000              3.000000
# 50%           1.429800e+04     740.000000              6.000000
# 75%           2.436700e+04    1251.116099             10.000000
# max           1.000000e+08    7510.000000             10.000000
#
#        Annual Income  Monthly Debt  Years of Credit History  \
# count   2.569840e+05  2.569840e+05            256984.000000
# mean    7.195308e+04  9.642635e+04                17.860925
# std     5.132807e+04  6.333951e+04                 7.083662
# min     4.033000e+03  3.900000e+01                 3.000000
# 25%     4.965850e+04  5.333750e+04                13.000000
# ...

# %%
df.head(5)
# Out:
#                                 Loan ID                           Customer ID  \
# 0  000025bb-5694-4cff-b17d-192b1a98ba44  5ebc8bb1-5eb9-4404-b11b-a6eebc401a19
# 1  00002c49-3a29-4bd4-8f67-c8f8fbc1048c  927b388d-2e01-423f-a8dc-f7e42d668f46
# 2  00002d89-27f3-409b-aa76-90834f359a65  defce609-c631-447d-aad6-1270615e89c4
# 3  00005222-b4d8-45a4-ad8c-186057e24233  070bcecb-aae7-4485-a26a-e0403e7bb6c5
# 4  0000757f-a121-41ed-b17b-162e76647c1f  dde79588-12f0-4811-bab0-e2b07f633fcd
#
#   Loan Status  Current Loan Amount        Term  Credit Score  \
# 0  Fully Paid                11520  Short Term         741.0
# 1  Fully Paid                 3441  Short Term         734.0
# 2  Fully Paid                21029  Short Term         747.0
# 3  Fully Paid                18743  Short Term         747.0
# 4  Fully Paid                11731  Short Term         746.0
#
#    Years in current job Home Ownership  Annual Income             Purpose  \
# ...

# %%
df.tail(5)
# Out:
#                                      Loan ID  \
# 256979  fffef5b7-be99-4666-ac70-2a397d2ee435
# 256980  ffffca93-aa8c-4123-b8ff-7852f6df889a
# 256981  ffffcb2e-e48e-4d2c-a0d6-ed6bce5bfdbe
# 256982  ffffcb2e-e48e-4d2c-a0d6-ed6bce5bfdbe
# 256983  ffffe32e-ed17-459f-9cfd-7b9ee7972933
#
#                                  Customer ID  Loan Status  \
# 256979  7211a8e3-cba4-4132-b939-222eed8a662c   Fully Paid
# 256980  616fef0c-8f09-4327-9b5c-48fcfaa52934   Fully Paid
# 256981  971a6682-183b-4a52-8bce-1d3429ade295  Charged Off
# 256982  971a6682-183b-4a52-8bce-1d3429ade295  Charged Off
# 256983  97281336-1e45-41d2-acb2-263ce56a590e   Fully Paid
#
#         Current Loan Amount        Term  Credit Score  Years in current job  \
# 256979                 3911  Short Term   1251.116099                   2.0
# 256980                 5078  Short Term    737.000000                  10.0
# 256981                12116  Short Term   7460.000000                   9.0
# ...

# %%
df['Loan Status'].value_counts()
# Out:
# Loan Status
# Fully Paid     176191
# Charged Off     80793
# Name: count, dtype: int64

# %%
df['Home Ownership'].value_counts()
# Out:
# Home Ownership
# Home Mortgage    124477
# Rent             109010
# Own Home          22923
# HaveMortgage        574
# Name: count, dtype: int64

# %%
df['Home Ownership'] = df['Home Ownership'].replace({'HaveMortgage': 'Home Mortgage'})

# %%
df['Purpose'].value_counts()
# Out:
# Purpose
# Debt Consolidation      203911
# Home Improvements        14915
# other                    14268
# Other                     9667
# Business Loan             4712
# Buy a Car                 3276
# Medical Bills             2868
# Take a Trip               1570
# Buy House                 1530
# Educational Expenses       267
# Name: count, dtype: int64

# %%
df['Purpose'] = df['Purpose'].replace({'other': 'Other'})

# %%
df['Purpose'] = df['Purpose'].replace({'Home Improvements': 'Buy House'})

# %%
df['Purpose'] = df['Purpose'].replace({'Educational Expenses': 'Busınes loan'})

# %%
df['Purpose'].value_counts()
# Out:
# Purpose
# Debt Consolidation    203911
# Other                  23935
# Buy House              16445
# Business Loan           4712
# Buy a Car               3276
# Medical Bills           2868
# Take a Trip             1570
# Busınes loan             267
# Name: count, dtype: int64

# %%
df['Purpose']=df['Purpose'].astype('category')

# %%
df['Loan Status'].value_counts()
# Out:
# Loan Status
# Fully Paid     176191
# Charged Off     80793
# Name: count, dtype: int64

# %%
import seaborn as sns

# %%
sns.countplot(x=df['Loan Status'])
# Out:
# <Axes: xlabel='Loan Status', ylabel='count'>

# %%
d={'Fully Paid':1,'Charged Off':0}

# %%
df['Loan Status']=df['Loan Status'].map(d)

# %%
df['Loan Status'].isnull().sum()
# Out:
# 0

# %%
df['Loan Status'].value_counts()
# Out:
# Loan Status
# 1    176191
# 0     80793
# Name: count, dtype: int64

# %%
train=df[ :5000]
test=df[5000:6000]

# %%
x=train.drop(['Loan Status','Loan ID','Customer ID'],axis=1)
y=train[['Loan Status']]

# %%
x=pd.get_dummies(x,drop_first=True)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
from sklearn.naive_bayes import GaussianNB

from sklearn.naive_bayes import BernoulliNB

from sklearn.ensemble import RandomForestClassifier

from sklearn.ensemble import GradientBoostingClassifier

# %%
g=GaussianNB()

b=BernoulliNB()

r=RandomForestClassifier()

gr= GradientBoostingClassifier()

# %%
test=test.drop(['Loan Status','Loan ID','Customer ID'],axis=1)

# %%
test=pd.get_dummies(test,drop_first=True)

# %%
model=g.fit(x,y)
tahmin=g.predict(test)
# Out:
# C:\Users\w10\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
g.fit(x_train,y_train)
# Out:
# C:\Users\w10\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GaussianNB()

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
gtahmin=g.predict(x_test)

# %%
accuracy_score(gtahmin,y_test)
# Out:
# 0.472

# %%
confusion_matrix(gtahmin,y_test)
# Out:
# array([[321, 528],
#        [  0, 151]], dtype=int64)

# %%
b.fit(x_train,y_train)
# Out:
# C:\Users\w10\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# BernoulliNB()

# %%
btahmin=b.predict(x_test)

# %%
accuracy_score(btahmin,y_test)
# Out:
# 0.684

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import BernoulliNB

from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import f1_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

b = BernoulliNB()
l = LogisticRegression()
d = DecisionTreeClassifier()
r = RandomForestClassifier()
gb= GradientBoostingClassifier()
kn= KNeighborsClassifier()
ab= AdaBoostClassifier()
mn= MultinomialNB()

def algo_test(x, y):
    modeller=[ b, l, d, r, gb, kn, ab, mn]
    isimler=["BernoulliNB", "LogisticRegression", "DecisionTreeClassifier", 
             "RandomForestClassifier", "GradientBoostingClassifier", "KNeighborsClassifier",
             "AdaBoostClassifier", "MultinomialNB"]

    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.3, random_state = 42)
    
    accuracy = []
    precision = []
    recall = []
    f1 = []
    mdl=[]

    print("Veriler hazır modeller deneniyor")
    for model in modeller:
        print(model, " modeli eğitiliyor!..")
        model=model.fit(x_train,y_train)
        tahmin=model.predict(x_test)
        mdl.append(model)
        accuracy.append(accuracy_score(y_test, tahmin))
        precision.append(precision_score(y_test, tahmin, average="micro"))
        recall.append(recall_score(y_test, tahmin, average="micro"))
        f1.append(f1_score(y_test, tahmin, average="micro"))
        print(confusion_matrix(y_test, tahmin))

    print("Eğitim tamamlandı.")
    
    metrics=pd.DataFrame(columns=["Accuracy", "Precision", "Recall", "F1", "Model"], index=isimler)
    metrics["Accuracy"] = accuracy
    metrics["Precision"] = precision  
    metrics["Recall"] = recall
    metrics["F1"] = f1
    metrics["Model"]=mdl

    metrics.sort_values("F1", ascending=False, inplace=True)

    print("En başarılı model: ", metrics.iloc[0].name)
    model=metrics.iloc[0,-1]
    tahmin=model.predict(np.array(x_test) if model==kn else x_test)
    print("Confusion Matrix:")
    print(confusion_matrix(y_test, tahmin))
    print("classification Report:")
    print(classification_report(y_test, tahmin))
    print("Diğer Modeller:")
    
    return metrics.drop("Model", axis=1)

# %%
algo_test(x, y)
# Out:
# Veriler hazır modeller deneniyor
# BernoulliNB()  modeli eğitiliyor!..
# [[ 62 417]
#  [ 54 967]]
# LogisticRegression()  modeli eğitiliyor!..
# C:\Users\w10\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\w10\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [[  95  384]
#  [  15 1006]]
# DecisionTreeClassifier()  modeli eğitiliyor!..
# [[309 170]
#  [214 807]]
# RandomForestClassifier()  modeli eğitiliyor!..
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                               Loan Status  Current Loan Amount  Credit Score  \
# Loan Status                      1.000000             0.269804     -0.383721
# Current Loan Amount              0.269804             1.000000     -0.136195
# Credit Score                    -0.383721            -0.136195      1.000000
# Years in current job             0.004281             0.005430     -0.000489
# Annual Income                    0.061282             0.023455     -0.033223
# Monthly Debt                    -0.016605            -0.001979      0.004855
# Years of Credit History          0.035379             0.014812     -0.010050
# Months since last delinquent     0.016261             0.002440     -0.005020
# Number of Open Accounts         -0.020833            -0.003111      0.007100
# Number of Credit Problems       -0.010179            -0.000062      0.000681
# Current Credit Balance           0.009292             0.003309     -0.003022
# ...

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True);

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure(figsize=(100,80));

sns.countplot(x=df['Credit Score'],hue=df['Loan Status']);
